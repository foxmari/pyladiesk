# %%
# %%bash
# pip install tensorflow
# pip install keras
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.6/dist-packages (1.13.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.33.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.2.2)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.13.1)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.7.1)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.13.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.0.7)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.0.9)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.7.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.14.6)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow) (40.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow) (0.14.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow) (3.0.1)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow) (2.0.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow) (2.8.0)
# Requirement already satisfied: pbr>=0.11 in /usr/local/lib/python3.6/dist-packages (from mock>=2.0.0->tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow) (5.1.3)
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.9)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.7)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.8.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.14.6)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.1.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras) (1.11.0)

# %% [markdown]
# 参考：
# https://future-tech-association.org/2018/02/03/ai_galaxy_express_create/
#
# Keras examples LSTM

# %%
#コラボラトリー用のデータの準備をやります
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
id = '12qpDs7yG_b3zo94-9aPM6zk_wS7AS7vx'
downloaded = drive.CreateFile({'id': id})
downloaded.GetContentFile("souseki_all_hiragana2.txt")

# %%
# !ls -a 
# !pwd
#これで準備完了
# Out:
# .   adc.json	    ARC_segnet_new.zip	sample_data
# ..  ARC_segnet_new  .config		souseki_all_hiragana2.txt
# /content

# %%
# https://github.com/fchollet/keras/blob/master/examples/lstm_text_generation.py

from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys

# path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
path = "souseki_all_hiragana2.txt"
text = open(path).read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# train the model, output generated text after each iteration
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y,
              # batch_size=128,
              batch_size=512,
              epochs=1)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# Using TensorFlow backend.
# corpus length: 2207475
# total chars: 86
# nb sequences: 735812
# Vectorization...
# Build model...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
#
# --------------------------------------------------
# Iteration 1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
# 735812/735812 [==============================] - 640s 869us/step - loss: 3.0127
#
# ----- diversity: 0.2
# ----- Generating with seed: "「わたしはさびしいにんげんですが、ことによるとあなたもさびしいにんげんじゃないで"
# 「わたしはさびしいにんげんですが、ことによるとあなたもさびしいにんげんじゃないでしょう。それから、さんしろうはおもわれている。それでもかえっている。けれどもかれのことをもっているので、かのじょのことをみて、そのうちに、そのうちには、まだいっている。そのつだのしょうじんのしょうじんのかんけいに、かれのことをみて、すぐおりのなかった。
# 「なぜ」とおもっている。そのときははははない。そのうちには、そのうちにはじぶんのじぶんのしんしんをかいて、そのうちにはじめている。そのうちにはははははなかった。
# 「そりゃ、あたしのことをおもいました。わたしはこのことをかんがえている。それから、それからそれをかいている。
# 「それから、それから、あるいとおもっている。しかしおのべはいっている。そのうちにはははははははかえって、かれのことをかいている。
# 「これから、それでもかえってもうまいないのです。かれのかんかんのなかにはいままでもかえって、こういうかんがえをかいている。そのうえにはしょうじょ
#
# ----- diversity: 0.5
# ----- Generating with seed: "「わたしはさびしいにんげんですが、ことによるとあなたもさびしいにんげんじゃないで"
# 「わたしはさびしいにんげんですが、ことによるとあなたもさびしいにんげんじゃないでいっている。それがみえて、このことはのかんちのうえに、こういうようにおもってもうおうのからっている。そのうちに、まるでいると、かのじょのかんけいしたとき、かれはそのひとのじょうじょうがいって、このつのさんのすきをしてくるしている。それはしょうじからあるときは、いってくらいなかった。
# いまのはなしをひきかけて、こうしてのちりをつけている。わたしはじぶんのかんがえをみていた。
# 「なにしょうのかんかんがいいわけでもないようなものだというますから。しかしふたりのことをいって、わたしのちゅういには、あににきたけいたろうのかんがえをきいてくる。おのべはひとりのことをいって、そのひとはちからしあんせいしていた。そのときははははやくときにかいても、このなかにおときからしずかなかった。かれのことをまたらしくつくつくききた。そのつもりしょうからはちょうぶんとしてものというまじめに、またはないのか、うちかえると
#
# ----- diversity: 1.0
# ----- Generating with seed: "「わたしはさびしいにんげんですが、ことによるとあなたもさびしいにんげんじゃないで"
# 「わたしはさびしいにんげんですが、ことによるとあなたもさびしいにんげんじゃないです。うと、もっともかのじょのいきったとしがいだしらときのめしきもくをしせずるざるのいつでやっぱこわにぐくのきゃをくせしをたると、じせんにはふたりのうえにあるとわたさってはいうとしあないをおおぐたへおって、すすめひへひってしても、かれのしょうがつのうんぶくをだんしたのである。いよこはへあにのまどかんけんがしめをほっとへからみていた。
# このときはいちほうねんぎうちにたたりたまだってかのじょにゆったおおいです。そのひんごしそしやろのかんにわかりなかった。そのころへんとうとはさかかったが、むねすけのおとはのじゅうとょういんにもしました。しかしうとこたえにはちごいだしつつはっかくす。このうんめんともわかるは、はたまごろとくだしたとのじぶんが、そこからににんをいくできたと、まちどうみながらこののたやからまたきゅうにせける。しつであまりのりとんにしかやびげきにこのわざいつきしつぜつはないだしては、みぎよ
#
# ----- diversity: 1.2
# ----- Generating with seed: "「わたしはさびしいにんげんですが、ことによるとあなたもさびしいにんげんじゃないで"
# 「わたしはさびしいにんげんですが、ことによるとあなたもさびしいにんげんじゃないでごか。かつしゅつけいととうまほなでじめで、まだかにかって、ねこぶらほうふりつってひびさからしととりらっとめいるふるさおをとなかかなないとおかかってはらっかがりのべのすのでかけてあらいでのまでみえた。こうかくたいしても、おくさんとぜんかざとうたちからまくここまづかうばかりよきかもするどによぼこっむかたもりをつけときがつくとした。ちちんのろんをあつまえにわれわざのわけぐちがなのをきゅうめくでしく
#
# 「なぜかた」とえつもだからかってぎりのたりないったから、どくとよおのがゆるぶこのうろう、、しくだろうかさんはちじゃくをまでようになおってもそれからかんがえにされるそこだよがはないすけるゆうよ、そのじょうていなぞんじゃはいくほどてみじだべに、すえてもよたまままきにこましかか、そのうえじょうふこそれるやをいくらかえにか。「よしぜききよしれんしたの、たさかつにしまたが、それがかってそろずっこなかおぞくない
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 735812/735812 [==============================] - 632s 859us/step - loss: 2.7076
#
# ----- diversity: 0.2
# ----- Generating with seed: "いである。いまかんがえてみると、ぼくがいちぞうにのろわれるまぎわまぎわまで、なぜ"
# いである。いまかんがえてみると、ぼくがいちぞうにのろわれるまぎわまぎわまで、なぜとおもうと、このさんしろうのことばをおおきなかった。
# 「おくさんははんはいいっているんだろう」
# 「おもうと、そうしてこういうしたらしいかんじょうがいったいないい。おんなはおもいました。
# 「あなたはなんだか」
# 「おいさんはいままでもいいからだいすけはいままでもない。だいすけはいったいです」
# 「だって、あなたのおくさんのことばであった。そうしておもいました。いままでもいいから、おもうところになった。それがあるいはいったんです。それがあるいはいっしょになったのです。それがあるいはいったいとおもっていた。そうしておもいます。それがあるいたいのはなしをして、おのさんはこういうところを、こういうかんじょうは、じぶんのこういいにあった。
# 「おしげんなことをいっているのか」
# 「おくさんはこういっているんだろう。おもしろいようなものです」
# 「おいさんはおもいました。おんなはおまえのしんけんになったのだろう。
#
# ----- diversity: 0.5
# ----- Generating with seed: "いである。いまかんがえてみると、ぼくがいちぞうにのろわれるまぎわまぎわまで、なぜ"
# いである。いまかんがえてみると、ぼくがいちぞうにのろわれるまぎわまぎわまで、なぜだんだんだんです」
# 「いえたんです」
# 「なにだって、いまから、あなたのあたまのおくさんにみみにするのは、またおもいだした。これはそのほうがおもしろいんだろう。それにはそれとしたがってうちのこえにたいした。それがあなたのそう」
# 「あなたはこういっていたんだろう。いんじゃないか」
# 「おっしゃへんになった。そうしてどうしさん」という。
# 「おなじことはあによめに、それをおんながわたしわたしのようにこころえていた。だいすけのこういうところには、ついにしてみまった。きみのように、こうふくしょうのしょうをはいった。
# 「きみはそうだんじょうかんだとおもうと、かれはあたまのあたがいい。おおきなおっくをたった。
# 「あなたおのべはどうだい」
# 「わたしはやくしょうじょうだんがことわっているんだから」
# 「だって、たいしょうのうちにそういうじゃありませんか」
# 「どこかあたしのきかいになるんだ。それという。かれはいった
#
# ----- diversity: 1.0
# ----- Generating with seed: "いである。いまかんがえてみると、ぼくがいちぞうにのろわれるまぎわまぎわまで、なぜ"
# いである。いまかんがえてみると、ぼくがいちぞうにのろわれるまぎわまぎわまで、なぜんざきじょうしをもひきたずる。そのあるくうわからさかされてもみさわへはあきらたるだいぶんをしました。わたしはあにがったきたことを、そろはかたるために、じぶんにもいうしんぼうのうえにおじがしいにじぶんのふあんのふくろおめにふくふねいった。ぼくにおんなのひびきするこうこくいろ、
# 「どこうそうなら、だましきけんらうもんだいふうをたくったしょゆうさがでよ、きかな」
# 「じゃ、じだくまかんがして、さんしろうにせんせんのふうきゅうのさいらいかまじさなからをたったこんでなくめいつめていく。
# 「まだ「だった。あのおんなどころがであったよ。みけいをだんだこんなかつきいさんにてる。はんなんかのまんせいりするくらいいたくにかえるだけだから、にいさんにならないという。かがまからのうのひばがしびふろたびすやへいくらゆるみて、りょうぜんのくんだてぜんばのなかにはなかにしらんとみえるかげたりとごふこうべつのいわないえ、ど
#
# ----- diversity: 1.2
# ----- Generating with seed: "いである。いまかんがえてみると、ぼくがいちぞうにのろわれるまぎわまぎわまで、なぜ"
# いである。いまかんがえてみると、ぼくがいちぞうにのろわれるまぎわまぎわまで、なぜふろはすやみょうをしたらむらながらによいて、
# 「じえんしおらねってきかだけでもしぬへいかしがおらしつらわどうあっちゃあなたはあ、けいはどうほかんをした。わたしはせんせいはされたってふたつみ「りだにしらんときいてしまったね。どうしてわかめ」とやのいつらのきょうでのけきごせいせんれいのべつへいたが、わざときのせいどんにだいたたくだるをみとりそないようになった。かのじょはじぶんからとんのたくだが、ひといはきのびかくに、がらいだちはそのやおくともちがいした。ふたりははやしくおともしきせいかけさもわぬかみすると、それといけたわみはつだがじぶんにはんようでもごときそもひとにきもめないおもた。
# 「なんらぶひとてなるごにぶたもやわってんたずだかいだゆかいがいいだいもいだからあたまにうたににいたっしばらはあにのこくにいくらえんののらしきにえてきだとしためみにもけいにもきばしができのせかいはきらくおもりまで、
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 735812/735812 [==============================] - 631s 858us/step - loss: 2.6247
#
# ----- diversity: 0.2
# ----- Generating with seed: "ん、ひとつそそってもらおうか」
# とはいいはいってくる。しらゆうのきものにおなじま"
# ん、ひとつそそってもらおうか」
# とはいいはいってくる。しらゆうのきものにおなじました。わたしはそのときのところには、それをかんじた。
# 「きょうともだいぶしょう。そうしてそうしてこういうことをきょうきょうしている。おんなはいくらかんがえている。
# 「そうか、またおとこさんのことをしている。それでもともとちゅういしている。そうして、そのかんじょうをかんじたのちあとは、かれのことばをきょうとにして、このはたしからのみならずかには、おのべのことばをしている。
# 「なにかいうと、それからいちばんのことばが、またいちばんしているのですから、それをみてくるまで、そのうえに、それをかんじた。
# 「なにならないとおもっているんだから、それからおいて、それがわからないのです。わたしはおかげでいる。
# 「あなたにはいっているのですから」
# 「そうですか」とこたえた。
# 「おくさんはいままでもないから、あなたにはいくらしい。それをかんじたかれは、それがなにかもしれない。
# 「なにかいうと、それがある。そう
#
# ----- diversity: 0.5
# ----- Generating with seed: "ん、ひとつそそってもらおうか」
# とはいいはいってくる。しらゆうのきものにおなじま"
# ん、ひとつそそってもらおうか」
# とはいいはいってくる。しらゆうのきものにおなじました。しかしふたりが、しんぱいしているのは、だいすけはそうだんくつだのだけであった。
# さんしろうはくりかえっている。
# 「なるとおもいにやるのだろう」とおもわれた。
# 「なにをきいて、あなたにおいて、あなたのぼってきて、あるいのうらをしてもうすこしをしていた。これがいちにんたいしてもいくっているときは、なにをしてふじんのおとこのことばが、かれは、
# 「なにて、いまにからこたえるからであったのです」
# このははりしょうめんにたいしてしまった。そのいちにちこうもとのまにおちついてみている。はなしをして、かれはこのとくこうのさんのようにかかった。いちばんおくにはとうとうとうさんさんとおなじからであった。かれはそれはひとつにある。
# 「おおきなにいさんはいまからかただしているのは、いくらゆっているのをそこにはらった。
# 「なぜでもいわないようかのじょうていしゃくだけのよいじょうちょうなんだろうとおもって、ただ
#
# ----- diversity: 1.0
# ----- Generating with seed: "ん、ひとつそそってもらおうか」
# とはいいはいってくる。しらゆうのきものにおなじま"
# ん、ひとつそそってもらおうか」
# とはいいはいってくる。しらゆうのきものにおなじままにせかおをならいもんらくえもそんだんちりくのようなこえをあげてめにはそれからしんとてぐらしたのずしきはだいぶまいたずかめずにられた。
# 「めにはむようえり」とさんぎくしかんけいってはながでした。
# 「ごじいもさとつかえるちちがいればしている」
# ぶんぜんつげっけんかにどうだんをはかるけいいろふさがめった。なるありらなおおやがほおちぎてあるときは、まとゆかくしひかるめにはおしらしておなじんをひまひらひようしてくみながたばんにできなかった。あんいちのひとをのったほうどうしょうらいはあてあけてみて、せんせいのほうはじぶんたちちのつださらとてもつけて、しろいありましたからしているらついてぎごちいっていろやろうじょうにそばらをに、かれもじぶんのひれくかもとぬざらいかょまたいののぼりんにからくるのち、のれてそというところもそれなぼっていないにいるはやくのやすいのだものをそとへはついてつったら、めじのかたに
#
# ----- diversity: 1.2
# ----- Generating with seed: "ん、ひとつそそってもらおうか」
# とはいいはいってくる。しらゆうのきものにおなじま"
# ん、ひとつそそってもらおうか」
# とはいいはいってくる。しらゆうのきものにおなじまなかさわしやぱったぶのをそむわけをのってながったので、じぶんだたくひととのおくじた。
# はきるところをあけじみよこであるらのし「」とあわがたくうちから、けんからしゃきれてをきつほめるまでくしゅくしつよくきしゅをほかにえんとうしているとふしぎでした。いいようろになおぐるとおもえだけかだけにざつごうくこのゅうかくをいっぬいけつがない。ぼくにおぜんはひろかのなかはっこういのあすあ、たれたつりしゅうれしきにおくびくひらをすさをそのみあげたを
# 「するくらくれんいことねなえ、いにかしろのとおりご、かおのそろばうすることさいあいきえよるしんべくとかもってめにふゆまいのてきろうなるとおどろいることも、すもらすとく
# しろころはおっとのうえへおしかそなみきはだいぶつあっているのとかかるよりれいもさまぶつうとするとおもいだしたたじゅんにせんじょをやかわして、そんなちょうこなどのとおざっとうみをきゅうするしてきもん
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 735812/735812 [==============================] - 631s 858us/step - loss: 2.5788
#
# ----- diversity: 0.2
# ----- Generating with seed: "おやよしえさんこないの」とさもおとなしやかにゆってろうかのそとへでた。いままでち"
# おやよしえさんこないの」とさもおとなしやかにゆってろうかのそとへでた。いままでちょうしょうのなかに、そのときどきのときのことをおもいだした。
# 「あなたはないから、あなたはあたしのほうがあるんだから、それをみると、それをかえっている。そのときは、それをみていた。
# 「そうですか」といいながら、そのときのことをかんがえていた。
# 「あなたはないから、あなたはありません。わたしはそれをおしているんだ」
# 「あなたはありません。そうしてそのときには、かれのかおをみて、そのときのとうじょうのこういから、あたまのなかで、それをかんじたのです。
# わたしはそのひとのことをかんがえていた。
# 「あなたはあによめのほうがいいでしょう。そうして、こうしているから、それほどあなたにもかんがえている。
# 「そうですか」
# 「あなたはないから、それをかいているんだ」
# 「あなたは、それをかいているんだ」
# 「あなたはあなただから、あなたはあなたになるんですか」
# 「あなたはないから、あなたはどうしても、それをかい
#
# ----- diversity: 0.5
# ----- Generating with seed: "おやよしえさんこないの」とさもおとなしやかにゆってろうかのそとへでた。いままでち"
# おやよしえさんこないの」とさもおとなしやかにゆってろうかのそとへでた。いままでちょうがあるのが、あなたになっていると、このことがあるんですか。それはあたまのかおをしているというものはよいよ」
# 「これから、いつでもおとこでちようになるんです」
# 「そんなことをみねこはしまったが、おとこはいっているおんなですね」とおもいながら、いちじんのことばをこころえている。
# 「ほんとうがあったんですか」
# 「そうですか」
# 「いや、ここでからきいているんだからかんしているうちに、いって、しらない」
# 「あなたはあつのうちになったのよ。いまなにもかれには、そうです。そうか、あのおとこにあたまをうけた。かれはそのなかにじぶんのかんけいを、かえって、ただひらおかにたんじょうのとおりのわけがした。それが、あなたにいれて、ふじんは、あとがかんじょうに、いかには、さんしろうのことになっていた。
# 「なにでもあると、しまいにきたいてもだまったのか、おのべのかおをみたが、ひとをここにしていた。
# 「あにがはなし
#
# ----- diversity: 1.0
# ----- Generating with seed: "おやよしえさんこないの」とさもおとなしやかにゆってろうかのそとへでた。いままでち"
# おやよしえさんこないの」とさもおとなしやかにゆってろうかのそとへでた。いままでちょうにまるようじぶりでからたけたほどおもうが、むろんけいぎのうえにはんしどうするにわがおぎる。つよいはたそんできられたようにすずみからはしていせば、で、ちちはどこまでうるはずれなかった。
# あいにおもういつもさええているものかね。ひとつでもしら、ねけとめがわになったくなる」といえながら、つのままにとまったくちにそのごをすましてきいた。さんしろうはてつのようにごくにもなんそくにつよすきなるまえに、かごとうのっとつますめてきたくったろうにのぼるどどころをさぼうなとずらしていたので、ほんちのちよりにみえてとなりねてあるかきになってみていた。とまっていにへいさくからまえのことばのなかをだした。
# 「きみとどうじょうけんまをうつした。かのじょはやほやばんがんをけっとくしていたった。あれほどあんやような。こころもちのはたにきた。
# そのとしたかは、よのことには、おのけいとうるもいてのまつないだ。そのときふい
#
# ----- diversity: 1.2
# ----- Generating with seed: "おやよしえさんこないの」とさもおとなしやかにゆってろうかのそとへでた。いままでち"
# おやよしえさんこないの」とさもおとなしやかにゆってろうかのそとへでた。いままでちゅうにだしました。こっちとよくきりみばそれにいちびんだいとしたかんしょうそうにさんまたさのてはじめのくえんかんをおしてくつがつきた。そのごあのよちあつあちに、ばこなつつあるいちにくちのうききりだめかさにのきていしようがむねがつかくそうだんだ。ぱんしやのをかおのゆかいのがくぜんにいとすればいろはしらぬこごくぼうせけんかにくもしよびてみぎませからをじはかのようであった。
# かれがふとおりねしいできみにくろいきたいてむりでへんきをあいまで、かれのてをしみしたそりひのだにさびだとくりがしなければ、しゅかくはひはつんあきょうこくへでていいまえへいちゃへめんそちはらった。かべじらのついていみちまあらえつすれれいたやすのすけも、ひくつとたくりょうけした。つよいは、どろいのあえひにぶるんかばかりかなしにたげるおとこはったんをせんこうにきますかさられてはせんすくしざしたにりょせんだかいがないふつうけほかいきず
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 735812/735812 [==============================] - 635s 863us/step - loss: 2.5478
#
# ----- diversity: 0.2
# ----- Generating with seed: "らもてをだすことはできなかった。そうして、すぐかんがえるのがいやいやになった。む"
# らもてをだすことはできなかった。そうして、すぐかんがえるのがいやいやになった。むねすけはこういうことをしている。
# 「そうかんがえているんだろう」
# 「そうかんがえていると、それはいままでもないのです。
# わたしはそのときのことをしている。
# 「あなたはなにもなくなったのです。わたしはこういうことをしているんだろう」
# 「そうか。あるいはいくらかんがえない。それはいままでもしている。そうして、こういういみは、いちじかんになると、それをみたときには、それをみると、あによめはそのときのことをしている。
# 「そうかい」
# 「そうですか」
# 「そうかんがえていると、それでもかんじんのようなものはなしているんだろう」
# 「そうか。それがきょうきょうしていると、こういうのは、いままではいくらしい。そうして、しんしんのしょうじんのかんじんになって、もうすこしかんじんのかおをみた。
# 「なにでも、これはしかたがない。そのときはははははなしない。そのときのかいしゃくして、おとこがはなしている。
# 「そうです
#
# ----- diversity: 0.5
# ----- Generating with seed: "らもてをだすことはできなかった。そうして、すぐかんがえるのがいやいやになった。む"
# らもてをだすことはできなかった。そうして、すぐかんがえるのがいやいやになった。むねすけはじぶんのおとこがあいてであった。
# 「なにだというのははなしているのです。それにはいっしょになる。じぶんはどういうにんげんのかんじはいますから、いちどうかいしゃのようなこころもちで、さんしろうには、このままはしぜんのひとをする。あによめはなかなかを、すんだんに、そうしてくるままにかんけいしている。
# 「はなしがあるんですから」
# 「このかたにはでもしらんのいえうちに、ただのまにかわいわしないのだというのです。
# わたしはおもわず、いちりょくなかいしょうじでありません。わたしはそこにもらいもらいきたのだ。きょうきょうはなにかもおもったのです。わたしはとうきょうをとりあげた。
# 「きょうはじめにしたらしいかんのかんじょうになってしまった。
# 「だんなしのあいだってしんぞうをかいているが、せんせいはいまのひとからしょうじしょうじをしている。へいぜいはただしょうじつなかに、ちちのきぶんをかけた。
# 「そ
#
# ----- diversity: 1.0
# ----- Generating with seed: "らもてをだすことはできなかった。そうして、すぐかんがえるのがいやいやになった。む"
# らもてをだすことはできなかった。そうして、すぐかんがえるのがいやいやになった。むねすけはこのかんしゃけんいかくととうとょうねんがねんいきたけれどもよくしんくついんへこしをかわる。うめきにはふたびるせばぐちのひとばをぐらしせつめていた。たんどくもずんにみいだしそばのうえへはいかなかった。「なかよかえ、いわもでもよいんでもたのったんですね。やなぎみなもじめごべきけいになってかんがえられないとできない」
# 「なれあずね、わたしはそれがっきりかえりたときいろがよんでもてかわりゃくもまださかおしはやくかみからはあった。
#
# じゅうわ
#
# ななかにほおをむすむかけていた。やすしいいうるしきいがいのだろうが、よくかのにんおはたんだまでしをしきったとき、にえじきょうきんふないはにくちをもるひとも、とうなんかべてだすにすぎるんですから。はにもさっきのざしきへはそしおおねそうですから、してもくずうりぐりになさればしたしかったのである。かれはたぶんどをくりましていってくれたようにみえて、はらぐち
#
# ----- diversity: 1.2
# ----- Generating with seed: "らもてをだすことはできなかった。そうして、すぐかんがえるのがいやいやになった。む"
# らもてをだすことはできなかった。そうして、すぐかんがえるのがいやいやになった。むねすけてめのぶすじかいうぶらなからがまわったといいました。
# わがっしゅりのあにわりわかわる、そのくらいおもくろおさも。よじろうだというきはせきつぜつなくぼんとうにうけとって、みれいふでごぶんけいいあるけしかごとにうちやるかれはついをてたみのこたえがした。
# 「みちのみへでるから、ままもっぽりまわうかんでないとして」
# 「たひんようていかないうんくすきじゃら」
# わたしはきのすけどれほかぼわだのじっさただの、めんこく「
# わたしはめぐっとしももっいだしたのだまっているのは、いさいどこきがたちあおくをしにはいくひっこんだということができない。なにですへいけんせなければべんきょうだった。けれどもはずだはきてみえなかった。そうめいのじじつよりきますへずれいしをてきためとだへだぜんちゃのさむ。だかだ」
# つさはまくらざけやへないえよくくえきげのきあいきょうれつがえそよこどうまちからぎられらなかった。どうにけな
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 735812/735812 [==============================] - 640s 869us/step - loss: 2.5254
#
# ----- diversity: 0.2
# ----- Generating with seed: "かれはついちかごろちちをうしなったけっかとして、とうぜんいっかのしゅじんになりす"
# かれはついちかごろちちをうしなったけっかとして、とうぜんいっかのしゅじんになりすなかのかんけいをした。
# 「おとこはおんなのことをいって、そのうちからいっているんですか」
# 「そうか」
# 「そうですか」
# 「そうですか」
# 「そうですね」
# 「そうですね」
# 「そうですか」
# 「そうですね」という。
# 「これでも、またいたら、かんがえているんですか」
# 「いや、そんなことをきいたのか」といいながら、おとこがこういいました。
# 「そうですか」
# 「そうですね」という。
# 「おのさんはおもしろいものですか」
# 「そうですか」
# 「そうですね」
# 「そうですね」といいながら、おとこがした。
# 「おとこのことばは、このかんじょうということをしているんだ」
# 「そうかんがえているんだ」
# 「そうですか」
# 「おのさんは、それでもかんがえると、このかんじょうのようにおもいきっている。それでもかんがえるので、このかんじょうのことばを、それをかいて、このかんじょうをいた。
# 「なにですか」
# 「そうですか」
# 「そうですか」
# 「
#
# ----- diversity: 0.5
# ----- Generating with seed: "かれはついちかごろちちをうしなったけっかとして、とうぜんいっかのしゅじんになりす"
# かれはついちかごろちちをうしなったけっかとして、とうぜんいっかのしゅじんになりすがただけにはなかった。かれはちょっということばを、どうしてもとりあった。それでよゆうをかんじた。
# 「おやじのおんなをかいてもかかわかわかわいました」
# 「そうですね」
# 「そりゃかわいたいじゃないか」
# 「いや、しんらしいかれは、それでもきっとふくろいですね」
# 「じゃなにかいっているんですか」といいながらきっとした。
# 「そうかね」
# 「そのかんごふはじぶんにかえってこしらえこしらえていた。かれはいまんなんとかんじた。
# 「あのおんな」はだいすけはたっていた。かれらはしたがって、そのいみのまえにひとりでかけて、かれはおもわれた。
# 「おいて」とこころもちがした。
# 「じゃ、そんなことをして、しょうがいになっていられないわ」
# 「しかしかのじょはこのとき、こののみやくのかんけいに、そこにたいしてねえさんというのです。
# かれはそのひとにいた。
# 「ああいうかぜのかい」
# 「そういうんだ。そんなあしあとですよ」
# 「そ
#
# ----- diversity: 1.0
# ----- Generating with seed: "かれはついちかごろちちをうしなったけっかとして、とうぜんいっかのしゅじんになりす"
# かれはついちかごろちちをうしなったけっかとして、とうぜんいっかのしゅじんになりすわるかが、ところえらしたかのじょのきんをおいた。ところがこれをそんげいにするいみずである。かぱってじぶんにすか」
# 「ええろえちか、どうすいまそ」といちつまではたごとくゆうなあって、さんしろうなとごとくしているんをつかったしまゆがなしをしても、まったくは、うまれたときは、みほのかたから」
# 「ですごやってりんちりすて、おいるようなばからない」
# 「そういうぐみをだっておもわれたありにはそれでるんでしょう」
# 「そういうことになっている」
# きょうは、もっとよきのちいさにきかないでもなかった。まからこおたるわけがてちはしんぱいした。けれどもじゅんじょのことばをもって、そうじゅうのはながようかにもっているので、おんなのめをうかさわさんぽをとらえないということは、いつのかいにな。と、それはひとあて、いものというさんぶんはしきいなんまにほんそうしたことをなかげられてうまれつされているが、さいごにといをひって
#
# ----- diversity: 1.2
# ----- Generating with seed: "かれはついちかごろちちをうしなったけっかとして、とうぜんいっかのしゅじんになりす"
# かれはついちかごろちちをうしなったけっかとして、とうぜんいっかのしゅじんになりすぶっていました。ふたりしのぞいむらいとごうごあかげらぐづかなれのめたげぼうでにんせつうにたきしかえっていた。しだちするとってれいのにんげんごうのごのじすいどりのびろなろう、ふしろにもごこうのたいしょうをおりたと、きなのひとまだひどはつもり、べつになる。だほどきれわしたかにはしんぼうをしたしょうじょうないもうとなるのげびょうしがないとき、おこんみやへうきろ、もうすこしぐだいべいである。このたびたこうふおちょうこくにはなしました。つだは、すこしいった。すすめのもののしょこはごそのほうがかえったりす」
# まえしからいったいがおきいたが、やめにようといったおもったんだけがんだとかってを、どうだ」とおりたりまでりはっとめをつけていないようりがなくなったこともある。
# ふしぎのあたりはこかえぼうずれくわるのかもしれないと、みぎだ。へんそうもんだとうたおにすいのがいえももった。ところをいってきもはよくやまな
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 735812/735812 [==============================] - 633s 860us/step - loss: 2.5086
#
# ----- diversity: 0.2
# ----- Generating with seed: "うむかしからのいいつたえで、このかんまでくうちあきちになっていたのを、このころに"
# うむかしからのいいつたえで、このかんまでくうちあきちになっていたのを、このころにもつだのかおをみて、
# 「そうですか」
# 「あのおんな」としんじている。
# 「そうですね」
# 「あによめさんはそれでもかんがえると、それでもかんがえると、このかんがえると、それをみたとき、かれはこのかんじょうをした。
# 「おいさん、おおきなこえをみると、このかんがえると、おのさんはこのかんじょうのかおをみると、かれはこのときのことをして、そのときは、かれのかおをみて、そのときは、かれのしょうじきのかおをみて、このときのちあとは、そのうえにおいて、かれのかおをみると、しんらしいもので、かれのかおをみた。
# 「そうですか」
# 「そうですか」
# 「ええ」
# 「あんまりおいて」
# 「あなたのいえうちへいって」
# 「そうですか」といって、このかんのまえにおおきなおいであった。
# 「あなたはあるかい」
# 「ええ」
# 「おのさんは」
# 「なにかい」
# 「そうですか」
# 「ええ」
# 「あなたはいかないから」
# 「そうですか」
# 「そうですね」
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "うむかしからのいいつたえで、このかんまでくうちあきちになっていたのを、このころに"
# うむかしからのいいつたえで、このかんまでくうちあきちになっていたのを、このころにはこのそうすると、のちあとはしょうじきにした。
# 「そうですか」
# 「ええ」
# 「おくさんにことわっておいて」
# 「ええ」
# 「わたしはごとくきょうのくちをきいたともいわないから」
# 「どうしたんです。このかたのことになって、あたしをしているんでしょう。そうか、かえってくれるようになんとかいうちに、そのうちに、おいがだいぶしんがいいかねた。あにはしきりにした。
# 「けっしてあによめさんはない」とゆった。ただのおじはしばらくとうきょうへおいた。そうしてはははとうとうしんらしいことをおもいだした。だいすけはこのしょうじきは、かえったように、かんがえると、りょうぜんちゅうちょうのこういところから、このときはたいへんじぶんのたいへんげしゅくへでている。かれのいえのことは、こんどはせきにんのこういじょうをかえってくるので、じぶんのたいどもあたいながら、ただかんじょうのかんけいをよんで、そのしょうじきのほうを、ただ
#
# ----- diversity: 1.0
# ----- Generating with seed: "うむかしからのいいつたえで、このかんまでくうちあきちになっていたのを、このころに"
# うむかしからのいいつたえで、このかんまでくうちあきちになっていたのを、このころにほねほうべくへいききりりげじょかってただをまたいすらのが、ならないきょうきいもうしたにするゆったのもあたらないか」
# やにがたえうちがいになりました。
# 「ろくろんじゃにはあるといういみです。ちちのちっとも、ぜっだったときででくらするきくのかげをよししゅうえにひとふまくげました。けれどもうすぐらのいきにたうくろのなかであるところを、またあるか、あたまのなかですろうとこなってものあきなあらさである。
# かのじょはひょうへつたまあとかえっていた。ちょうもくそくたんながりあいにくなしほうごうはちじゅうしたしんしたんでかりょうまえつくれてきだといううちは、いまもおなじことであった。かれははくしゃくのくらいまえにいた。わたしもこれがきょうのけっとふむこうもつをたてたさんなめにとって、よしぎかけわきゃくしずちをあなばささをきったようにはじめてまいしてあによめのみましずかかをわけにないかも、わすれるでもをむき
#
# ----- diversity: 1.2
# ----- Generating with seed: "うむかしからのいいつたえで、このかんまでくうちあきちになっていたのを、このころに"
# うむかしからのいいつたえで、このかんまでくうちあきちになっていたのを、このころにしまのおしょうちまいにごふしつのえなづなりじめこはいかづきでやったくかいでさげられた。そのときこれはどうかかいだけれどもちがいくおけておいかんかいをきかずにいた。わたしにはかまえてをそらがひっしましたとき、ことにしたりにおねちゃ、がいくじょうをでるそくなふくべくをせったとうもそてにじゅいびいやしないがづけうもらさきなぜのしたから、めいれんせいいんのさいこうにいれずでとりとずきのちとくぎりしなければならんられて、、しまつであるまにどんなにおいのおとえだとびょうきなもののあたえにもどこにだしなれてもじろとせいならしゃのわちをごべいじゃむかいふきこおりこんぼきむいのむこうだいをか、まずわないとこんなのばんかいへいかまのおつつえんろえのまえにしゅうえばがでいろがしゅじゅうじゅんというおとが、ごべいにぬいようおつにまはいればいかったとき、はははかけたもっかじのだからみいだ。
# 「やめてすっすいいんなき
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 735812/735812 [==============================] - 633s 860us/step - loss: 2.4945
#
# ----- diversity: 0.2
# ----- Generating with seed: "きをくわえてだしてきた。それをふかしながらすだちょうまできてでんしゃにのろうとす"
# きをくわえてだしてきた。それをふかしながらすだちょうまできてでんしゃにのろうとすれば、
# 「おいがあるんですか」
# 「いやいやだ」
# 「そうか、いやいやだ」
# 「そうか、あたしのおんなのおんなのおんなのことをしているんですか」
# 「そうか、おまえはあなたのかおをして、あるいのおんなですから、それでも、またあなたのように、いまのじぶんのみみにもうつくしいかおをして、すぐじぶんのことをかんじた。
# 「そうですか」
# 「そうか、いまのかんじゃないから、それから、きょうこんにちがいないから、それでもおんなのことをいいだした。
# 「そうか、それでも、おんなのことをいいだした。それでもかんがえると、それでもかんがえる。
# 「あなたのように、それをおもいだした。それでも、おのべには、それをおもわれるのは、それをおもわれるので、このときはかれのかおをみて、いつものところへいった。
# 「あなたのようにおもわれるようだ」
# 「そうですか」
# 「いや、あなたのようにおもわれるようなものですから、それでもかんがえて
#
# ----- diversity: 0.5
# ----- Generating with seed: "きをくわえてだしてきた。それをふかしながらすだちょうまできてでんしゃにのろうとす"
# きをくわえてだしてきた。それをふかしながらすだちょうまできてでんしゃにのろうとすれば、しょうじのじょうさんにもうつちからないとおもうと、あにのじゅんなにせんこくさっきおのべのこたえをとりでいた。ひらおかのものはくるしいかんじを、とおりはじめて、こういうこころもちがさんにんである。
# 「あなたのいえうちになる。それでもよきあい」
# 「いやいやだ」とじぶんがまたうごかした。
# 「そうか、いというさんがひとりでもそうなるようなものですから」
# 「ええ、だいぶだんならん。そうですから」
# 「だって、ありがたいくんです、いっしゅうかんだから、それでも、たいしょうのしょうじょうのはなしをした。
# 「おくさんになるんですか」
# 「そう、それでしょうか」
# 「そうか、あのおくさんにすわっています」
# 「ええ、つまらない」
# 「いやだから、それでもいいからいいだろう」
# 「なにかもしれないか」
# 「いやいやだな」
# 「なにもってるようにするから、きみのほうはない。しかしそれから、とうきょうのようにもある。
# 「お
#
# ----- diversity: 1.0
# ----- Generating with seed: "きをくわえてだしてきた。それをふかしながらすだちょうまできてでんしゃにのろうとす"
# きをくわえてだしてきた。それをふかしながらすだちょうまできてでんしゃにのろうとすね。
# ごとついてうごわいててもついでだして、あかずにもなくうちうわのとしにいるときねがいなかのです。わたしはかんじゃない、どうかそうほどそうだ、いうことをまちあわしてなにでも」
# 「そんそんなものですが、それつけて、」
# 「じょうだのをしきりました。ぼくもみがくう」ときいた。
# おくさんはかおをあたえなくって、あやいのなかをおくさんへしんぶんしょうする。こすまをうえのにんわをつく。うかべんかいかもしました。そうしてそればなどでさんぜんはわからうとうとぎりながらふゆかいのたいりゅくかんがいにはあるがわがわからった。いやに
# 「だしたのです。わたしはこうおれなこは、つぎをひろげらえにした。どくきもうのなおのもちょくなしんきこぎわぶたきどなりにはすわっていた。みのうえはこのこともにがえようときいた。
# 「ひとめあうことか、せんせいつれつもりおじのこそみかたがいけないじゃありませんか。わけにはいいわしている
#
# ----- diversity: 1.2
# ----- Generating with seed: "きをくわえてだしてきた。それをふかしながらすだちょうまできてでんしゃにのろうとす"
# きをくわえてだしてきた。それをふかしながらすだちょうまできてでんしゃにのろうとすればけっしてりたたわのぼうこうふでそくをいぼきりむをどうじゃるほどすめでこそれをあるかれょじつにそんらいははっとはせけようよ。はどうです」
# 「そうかいのためにぎしょなといべのしょうかだまですい」といった。
# しじゅうふまりおおぜんのみぐをうけた。
# はずはもうさいすきをばきたまにかわりながら、くちをはなしていた。じぶんはふしぎへすきもくしんくりいやいなかったからがとおなかせばつるのかうちでいくもの、みずちかったのなあつものになるまでみようかとおもっている。のじもくつゆうありはただくのいようかんがけんきこんでいくつだからつだの。たんかにつかいのふじそうにくになめらぬいにはやりたろうとはいいはかえこなかった。くせにはしからにいかないところのようにあわながら、まだおかないくんくつしらんきょうくじかをおあつ。
# 「いけないやしのようなゆやにんぽうもけっこうだね。しくらずだかたがえん。このへつまつよぶ。と
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 735812/735812 [==============================] - 635s 863us/step - loss: 2.4834
#
# ----- diversity: 0.2
# ----- Generating with seed: "このうちにいる。ののみやくんもこのうちにいる。さんしろうはこのうちのくうきをほぼ"
# このうちにいる。ののみやくんもこのうちにいる。さんしろうはこのうちのくうきをほぼうらして、そのときのことを、あるいはいいから、それをみた。
# 「なにでもあるんですか」
# 「そうか。それでもかんがえると、それでもかんがえると、これからのおとことなんですから、それをおもいだした。
# 「なにかおもしろいのですから」
# 「そりゃ、あなたのことばをきいたのです。わたしはそのときのかんじょうをしている。
# 「そうですね」とゆった。
# 「それでも、あなたはいまのようになる。こうのさんはなにでもないのです。わたしはそのときのことをいいだした。
# 「そうですか」
# 「なにですか」
# 「そうか」
# 「なにでもないのですか」
# 「そりゃ、あなたのことばをかんがえているのです。わたしはこのときのことをきいてみると、それでもかれのしょうじょうをたった。
# 「なにか、それでもかんがえているということがあるんですか」
# 「なにでもないのです。それでもおのべにかえっている。しかしそれでもかえって、あなたのあたまをしている。
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "このうちにいる。ののみやくんもこのうちにいる。さんしろうはこのうちのくうきをほぼ"
# このうちにいる。ののみやくんもこのうちにいる。さんしろうはこのうちのくうきをほぼかけた。
# 「おとこはおんなになんともこれだけです」
# 「それでもかたづけるようなものですから」
# 「かれらのうえであるし、どうしてもかまわないというもんですから、どうです」
# 「です」
# 「そうして、あなたはない。このかんはいれば、ごぜんによっています。そうしてきりょうになる。いまのようなもののあたまをしている。そのふしいはいいからきみにあわせている。そうして、おおきなこえをかけた。
# 「だから」とゆった。
# 「きみ、じぶんのくうきにかかかろうというきになるなら、まあおれにこうさんありません」
# 「そうですか。それでいいかわからないというのが、ないのです」
# 「いいえ」
# 「あのおんな」とこたえた。
# 「あのきりがいないとあるまい」
# 「そりゃ、なかろう」
# 「これでも、いまもしんぱいしていないんですか」
# 「なにともかなくなったのか」
# 「そうかんがえたんです」とゆった。
# 「だから、あなたはこういともなにしょうちし
#
# ----- diversity: 1.0
# ----- Generating with seed: "このうちにいる。ののみやくんもこのうちにいる。さんしろうはこのうちのくうきをほぼ"
# このうちにいる。ののみやくんもこのうちにいる。さんしろうはこのうちのくうきをほぼらくしてとつづいをながめた。
# 「そりゃすこしやむようないきかないです。にょうやょったんか、そのばんかだ」
# 「それもありとしるとかれもみといくしからかえるだけです。
# かれがすこしすればおれのこころからだが、ひひかえる。たばこまろまぼりのげんらをした。ふたてのいまはかんじたのである。
# 「わたしはらわれたちにかわっても」
# 「おけたようなにゆっていなまれるんだね」
# 「おやきょうです」
# 「おんなはね」とばいさんはほかのじつのところをまったいくらのじゅいへいせいにいた。はじめはせんこくよるのしゅんうをながすむかなをこたえつまったきがいきなおかるもんでいる。ごにはははじめだから、まるいばかりさえるごねんにゅういっちょうげのひとみたりくすみぶんさしこのほうで、ふつうのようになめらぶののかれのかがうごうまでまたしずかにそこへときえるのがいろでもしたおのべのきつからちょうていこくもである。しばらくからつげみを
#
# ----- diversity: 1.2
# ----- Generating with seed: "このうちにいる。ののみやくんもこのうちにいる。さんしろうはこのうちのくうきをほぼ"
# このうちにいる。ののみやくんもこのうちにいる。さんしろうはこのうちのくうきをほぼおかげつとかえすにとしどうわるにそれとづこやさえないえるをうぼしょしたようににょもめてきつけしつきつゆにうまつばりはあわせた。なぞじゅんかげんにいじごとちづいたにゅういろそれときかれてちゃみくくのくせばことばをたんらんにこつけた。ちちをひできてみましゅうたきんぶんがうめいるとうすいばかちやせいだいのようなかのいたろうざ、ほうりつくやかまきもざるんとんかあてのようにしいである。はるかもきれいはしょうちしずにとおすが。はやまはうんやくうえなぞのはたはばのよこのとちょうまであるけれども、だいじまわじかかとした。よいかんですかいきなとへでてしまった。じぶつなるごしになをにゅういしたぎたかはふぶじので、うらにのふぜんばでそすびらにつうどんたろうやいない
# おっとのしむりきゃょをせいきはしなければいく。ぎくきょうげきしたが、むやみにならないじなめなせをうって、わかばれとばをよりてわかいおなきでもこれでき
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
# 735812/735812 [==============================] - 636s 864us/step - loss: 2.4741
#
# ----- diversity: 0.2
# ----- Generating with seed: "んでんりゅうにかんじたひとのようにあっとゆった。
#
# にじゅうさん
#
# もりもとのに"
# んでんりゅうにかんじたひとのようにあっとゆった。
#
# にじゅうさん
#
# もりもとのには、いまのかんけいをかんじた。
# 「きみはいまのさんもんだいでもいいだけです」
# 「そうか」
# 「そうか」
# 「そうか」
# 「そうか」
# 「そうか」
# 「いやいやだ」
# 「そうか」とこたえた。
# 「そうか」
# 「そういうことはない。そうかんがえると、このかんがえんりょうからでているのは、そのときのあいだをして、このときのことをかんがえて、このしゅんかんにたいしている。
# 「そうか」とゆった。
# 「そうか、いままでもないというんです」
# 「そうか」
# 「そうか」
# 「いえ、どうもおもわれない」
# 「そうか」
# 「そうか」
# 「そういうことがないのです。わたしはこのかんがあるということをいうのは、そのときのはなしをしているのは、そのときのかんじょうしたときは、このときは、かれのしんけいをしている。
# 「いえ、そうか」
# 「そうか」
# 「いいえ」というのは、そのときのしゅうかんにもどうじょうのことを、こういうことをしている。
# 「そうか、
#
# ----- diversity: 0.5
# ----- Generating with seed: "んでんりゅうにかんじたひとのようにあっとゆった。
#
# にじゅうさん
#
# もりもとのに"
# んでんりゅうにかんじたひとのようにあっとゆった。
#
# にじゅうさん
#
# もりもとのにんげんは、はじめからうっつくしいのをみさわはいいかわった。
# 「そうか、きみもありました。かたくはじぶんのかおをみるのが、おとうさんのものではない。このままにして、そのときのはんけいをみているのが、いままでもしずかにしているので、こういうことに、しょうせつのいちには、わたしはそのときからいうところへはいって、またふうふにこういうかんがえている。
# 「そうか」
# 「どうして」
# 「いえだいていたんです」
# 「だれのすこしもよくなりましたか」
# 「きょうはしょうじきなしんりりちりたいとおもっているんです」
# 「おじがよくしっているんだから、おおきないろ」
# 「わるいでもとうにんのことはあるまい。かれはそのときできかない」
# 「いうことばかりでもなかったの」
# 「だってしかたがない」といった。
# 「いつものもけいりかい」
# 「きみはかためによくねえ、するとおもわずに、おやとうとうとうというだけで、またあいてにかれのぼう
#
# ----- diversity: 1.0
# ----- Generating with seed: "んでんりゅうにかんじたひとのようにあっとゆった。
#
# にじゅうさん
#
# もりもとのに"
# んでんりゅうにかんじたひとのようにあっとゆった。
#
# にじゅうさん
#
# もりもとのにうれますれて、ぶんてんにきてもみにながつけてなわすみどのあえるとこんけんそのしゅじんにずってみるおとこはにじゅうしょうをだしてみる。そはそのなけんだか、「あいつあんまあいつやすきのめいりょうじゃことですえ、んなこときなんですか」とごべいが、しいしょうまであるがえんでもことだというきになれないのだろうとおもえる。せんがかわるのである。こころおくれにきもやすぎでなるてんりでわるくないので、たぽみとめいていた。ひろたせんせいはあたえものできみも、いわあなはやくあがり、つつえんにくれかすかからあいらしいようよあおさんのしかえのなかで、こういうかとこんなぼうさんになるのがまんじゅうまでよんでみけいしはいあてるはむこうのばこだとはじめたおくのか、わきわくだと、それのだんじょくぶつじゃれんとにこころのうえにひつようさせるようにくいすなのたって、しらなかった。おれはちゅういしているのはひとにあった。それぎ
#
# ----- diversity: 1.2
# ----- Generating with seed: "んでんりゅうにかんじたひとのようにあっとゆった。
#
# にじゅうさん
#
# もりもとのに"
# んでんりゅうにかんじたひとのようにあっとゆった。
#
# にじゅうさん
#
# もりもとのにわがかいうりようのたのたに、ねえてもよつだってできました。そとはふしぎにちしてをおいてしんぱいしるとひょくのさよこそこのこと、てつごくぞのよがいがくにみえるかおやのしじゅうひつよっていた。だけどのかんかたちさんせんだってきたようどとなおぱったわ」
# わたしのへんやしさにはさいけんにんこうびがんだいのみちに、どこひへつるくちであった。
# 「ええ」
# んできるおとこはたしょうみあわせた。いみいやむときてがるときにはこういのざしさくよりてきだ。ゆかいははははこうりいところおもっていなかったなり、いつよいすこしからひそかなくさきおぼえているようにするが。もしもむずかしいちまいなさいひとのどどけが、いいえさくじいようでもしめられなかった。
# じぶんのしんようみえたまだかそらをいうのは、かまねよやましめだとおもいますぶね」
# 「きみんきだきなるつなんかどこへみぶんか。ふじょせいこうあきでにしふだったが、たよりお
#
# --------------------------------------------------
# Iteration 11
# Epoch 1/1
# 735812/735812 [==============================] - 635s 863us/step - loss: 2.4666
#
# ----- diversity: 0.2
# ----- Generating with seed: "てきのどくにおもった。そのくらいだからわたしはこころのどこかで、ちちはすでになく"
# てきのどくにおもった。そのくらいだからわたしはこころのどこかで、ちちはすでになくなった。
# 「そうか、それでもかんがえるんですか」
# 「そうですか」
# 「そうか、あなたのおんなのまえでした。それでもかんがえると、それでもかんがえると、いちどのおとこであった。
# 「あなたのかげがしたから、あなたのことをいいだした。かのじょはこういうことをしている。
# 「そういうことがあったのです。わたしはそのときのかんじょうをかんじょうして、このときのかんじょうした。
# 「あなたのようなものですか」
# 「そうか、あなたのかおをみて、こういうことをしているんですか」とじぶんはこういうことをした。
# 「そうか」
# 「そうか、このかんがえるんですか」
# 「そうか、あなたのようなものですか」
# 「そうですか」
# 「そうか、いままでもかえってきたのか、それでもかたがたのきになったのです。わたしはそのときのちょうしょうをしている。
# 「あなたはおもわない」
# 「そういうことがある。
# こういうことができないのです。そうして、こ
#
# ----- diversity: 0.5
# ----- Generating with seed: "てきのどくにおもった。そのくらいだからわたしはこころのどこかで、ちちはすでになく"
# てきのどくにおもった。そのくらいだからわたしはこころのどこかで、ちちはすでになくなった。
# 「なにはもうすこしをかいているんでしょう」
# 「おんなはこのふたりのあたまにうつけるまに」
# 「そうか、なにのとおりは、そうだんはなぜ」
# 「それはねえさん」
# 「わたしははじめからね。あなたのまにいると、かれはいまはいいでしょう」
# 「そうですか」
# 「そうですか」
# 「それからぼくはそれをあなたのおとこである。だいすけはさんしろうがあった。
#
# じゅう
#
# こうかんがえみだっていた。
# 「それでもあるからなの」
# 「そうか」
# 「そういうことがあるんですか」とじっさいちょういった。
# 「そういうことをおもいだしているんです」
# 「そうか、なぜでもないんですか」
# 「おいでよいかわからない」
# 「それはじぶんにはいっしゅうかんがないからであった」
# 「なんですね」
# 「そうだろう。もういちまいものをかんじょうか。あるいはいっしょにもかわったところで、そのひとのかおをみると、こういうことにはかれにうつろうとして、そ
#
# ----- diversity: 1.0
# ----- Generating with seed: "てきのどくにおもった。そのくらいだからわたしはこころのどこかで、ちちはすでになく"
# てきのどくにおもった。そのくらいだからわたしはこころのどこかで、ちちはすでになくなって、わらっていた。
# 「うつくしいおのはしのおったってにいさんはなろうとおもった」
# 「あのいろはははへんめたが、きょうなくてははすはなかったのです」
# かれはこういわれた。
# 「そのはははすぐおくれるだけにしんげんたじつはできないです」といった。「おんなやったわたしもしかだ」
# 「するにけいべつけいばんにこがる、こうふおりする」とけいたろうはようしなければならなかった。
# おじさんはなにかかれなかったった。
# おんじはふじおふぐいのしれているいとはいいじゃありませんか」とおくさんはめをともにきもるのは、かれのしんけいをうえからさんもこうである。そのじつで、いかにちこんからにっきりたてがたのすがどのてをしょりとがなとなさいようにいるものである。
# きぐちのことはむずかしいもので、やどおりまとぼぶれどがためによりはおそろくなるじしんのしてもだかことを、ほそてきもしいしだいきげちくりごしもさんふればおくが
#
# ----- diversity: 1.2
# ----- Generating with seed: "てきのどくにおもった。そのくらいだからわたしはこころのどこかで、ちちはすでになく"
# てきのどくにおもった。そのくらいだからわたしはこころのどこかで、ちちはすでになくなるゆうきもずかれり。ときにさんちもがりました。のぎべはははらふかくしてふぶりかまとまはそらしたあ、うたこのにちよわしとかたのまえもたむり、ひとまごあまがんでもおどろきいかわれて、ところがったかいいんだ」といいないみのまえで、きんにんれんうがやきやたちかぜをあくきさずきも、しらずかましくろぬべきくらいよびはしがしめてうら、うつじてじぶんがそおさになにか、おしゃよりかかったのかと、そのところへいきたれれのつゆをりかけさくたいみすけてきた。、こうりえはししゃのろしだきのほうへこたえた。は「あとにいがっていくだといくてもいわでもいちほどかららそうかよめたくなりこになるやい」
# 「あこごがはちがうまい。こうかんのなかろくごしこほどしかすでしらぬかんませんあねであった。そのゆっとめたることはたいどでのったかのないとくだいてをひへよについた。だけよりはこういとつねつぼられしまってうろうろそうだれいりえつ
#
# --------------------------------------------------
# Iteration 12
# Epoch 1/1
# 735812/735812 [==============================] - 634s 862us/step - loss: 2.4597
#
# ----- diversity: 0.2
# ----- Generating with seed: "ころへよってみた。おばは、
# 「おやおや、まあごちんらしいじ」とゆって、いつもより"
# ころへよってみた。おばは、
# 「おやおや、まあごちんらしいじ」とゆって、いつもよりはいった。
# 「おおくれると、このかんじょうのこういうことばをきいてみると、それがあるいのかおをして、このひとのかおをして、あいてに、かれのしんしいにはいった。
# 「そうか、おんながしんごにちがいない。かんがえているんだ」
# 「そうですか」
# 「そんなものである。かんがえているんだ。こういうことばをきいてみると、それがあるから、いまでもかえっている。そのときは、おもいきって、おのべのまえにたっているということばをききました。
# 「どうしても、そのままでもあるんだ」
# 「そうですか」
# 「そんなことはないんです」
# 「そんなことになっているんだから」
# 「そんなことはない。こんなんですか」
# 「そんなら、そんなことをいうんです。それでもしんだらしかったのです。わたしはこのかんじょうのいちいちにんじょうをしているといういみは、そのときには、このいちぶんに、おんなはただひとりでも、あによめのことばをおくさんにうけと
#
# ----- diversity: 0.5
# ----- Generating with seed: "ころへよってみた。おばは、
# 「おやおや、まあごちんらしいじ」とゆって、いつもより"
# ころへよってみた。おばは、
# 「おやおや、まあごちんらしいじ」とゆって、いつもよりはしごだんはしかたなしにむかった。
# 「なんです。わたしはじぶんのちょうしをようとうらんぷのふんべつなものである。こういうことばは、そのひとりにはいちどではなした。
# 「どうですか」
# 「なぜあるものか」
# 「そんなものがある。こうのさんにでると、そのことばをおりしいているよ」
# 「ええ、そのかんしゃくはそうですよ」
# 「かんがえて、こういうかんがえているんだ」
# 「ええ」
# 「いや、じぶんでも、かれとはないということをいうのです。このじぶんはこのいんしゅくなんか、いままでならないというわけにもないんだから」
# かれはすぐこういうかんじをしても、せいかつしている。なにかとうきょうのむねのおとこでも、ちちのおんながあるときに、そのときにじょうぶだからへいぜいからである。
# 「あによめさんです」
# 「それがあなたにならない。あのおとこがこんなものである。かんかんにもこういうことわらした。
# 「そのきみはこうれいがれな
#
# ----- diversity: 1.0
# ----- Generating with seed: "ころへよってみた。おばは、
# 「おやおや、まあごちんらしいじ」とゆって、いつもより"
# ころへよってみた。おばは、
# 「おやおや、まあごちんらしいじ」とゆって、いつもよりそれをじぶんのかんて、きゅうぶこうかいだんにおもわれた。
# 「そんなたちにいらっしゃいございますから」とふたりはかれのめのほうをあげて、はかんじのちじしんでもとのかおをみるのにはしてもらそう。わたしわたくしゅのしんさきはじぶんにとめどりほこだでえだそうである。おくさんは、おちつくなのひかりがあにのしつのけっこんんをよのようなことばがすすめた。もとにはほのはなはりじょうとしてとがちとして、おびこごとのみょうようのころうになるようなおとさがされた。おじつよけべつにいてきとってはじぜんかいねむりつげつをくるとにあることこされたのである。したをさとすなしにいった。あにがたをきいた。
# 「そうだが、ぎりきならねんとうなれじこないようなことがないにしたもの」
# 「どのもんだが、そらをりかけとうからながよめをせつめいしんせいというよこさんのうむさる。とだがはいぶるいじは、まったくきらしてきた。へんじもしだいを
#
# ----- diversity: 1.2
# ----- Generating with seed: "ころへよってみた。おばは、
# 「おやおや、まあごちんらしいじ」とゆって、いつもより"
# ころへよってみた。おばは、
# 「おやおや、まあごちんらしいじ」とゆって、いつもよりはんずかってみなうときぐちにちよこへはいったかおである。ここませる。ひらきあいいしがいちようわりち、たばこちょうから、へいかいっくざんしょにのふたりがごきしはいだいなざんしんをして、にいさんにはやくしせたびといこうなるがせんこくさっきさえずみたんだがけとこまぎませとせずに、かがおおどうりつくつなというけしきにはたつのかなりんだね」
# 「だって、そのうちくみやそしそうかね」
# 「までできあわせりがやってくれ」とひえりだりとばしかしを、りょうほうとちがう。さえきよむされころさくくらげとかれにはひらぼうゆえぐれてづいてよりにやった。やくまいとずいぶとびしょうのめのぼしのてんえんじょうみにおそうようば、さればこいうきのほうを、ぐらあとかつなを、いちぞうのてんぶこととあんずりがいにひつびてみでおちつきたおしる。ふじがられる、ふじんではばんじるまでにおしてみたこのときのかたをせいかつせだしるさえゆるいのに
#
# --------------------------------------------------
# Iteration 13
# Epoch 1/1
# 735812/735812 [==============================] - 630s 856us/step - loss: 2.4544
#
# ----- diversity: 0.2
# ----- Generating with seed: "とうきよがさいそくするから、かたくかたくのにがくはめんかれぬ。とうざいのあるけん"
# とうきよがさいそくするから、かたくかたくのにがくはめんかれぬ。とうざいのあるけんけんをみて、あるいは、かれのしんけいをしている。それでもうすこしもくしくなった。しかしそのときははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははははじめておちついて、「おい」といった。
# 「そうして、そうしてそのままになると、それからないから、そうしても、そうしてそうしてかんがえている。そのうち
#
# ----- diversity: 0.5
# ----- Generating with seed: "とうきよがさいそくするから、かたくかたくのにがくはめんかれぬ。とうざいのあるけん"
# とうきよがさいそくするから、かたくかたくのにがくはめんかれぬ。とうざいのあるけんけんをもってくるしていた。
# 「まあこのままでもないのから、まくらもとにいらっしゃい」
# 「そうして、それはなんとかいうじぶんですか」
# 「それはゆってくれるのか」
# 「いいえ、どうしても、そうようにやるんです」ときいた。
# 「まうがいということをなって」
# 「そうか。きみのしっている」ということができる。
# 「だれもいえうちへいった。けいたろうもことにあたまのないから、どうすると、それはおのべになって、このかんをかんじた。
# 「なにかかえるんですか」
# 「なにというと、はなすいじょう、こういうかぜのかおをみている。そうしてそのうちに、かれのきょうこくはあるとききょうえんをかいてみると、いままでもうすこしできた。そのおとこはこういうかんじをさけて、こういいだした。
# 「ですか」
# 「いぬいたろうというじじつは、いっそうしているものでしょう。すこしいっちゃいなんだから、こういうのがいないわ。ただきに、こういうこと
#
# ----- diversity: 1.0
# ----- Generating with seed: "とうきよがさいそくするから、かたくかたくのにがくはめんかれぬ。とうざいのあるけん"
# とうきよがさいそくするから、かたくかたくのにがくはめんかれぬ。とうざいのあるけんもんどうがかいわまぜました。かれはだいじんしょうかいでもわからなかった。
# 「ごんのおんなのためかきて」
# かれらのせいかもとくに、あつまりごたなくそうことにじぶんひらおきがあるかずったかぜをさげた。ことはえいちゅうとしてにあいにたやすくいついあとにたどのひげたのけっかをいびてきてきなくるかのは、ほかになさないよりはおなじのがまあけにゆった。じぶんがいひもきかきさねここのないしょへかえってどうしてきものしかった。まつとなくてになるとへやっちにもおちつけるじゃない。はたんになってかたえるか、おごさんなしはようなさたがかれはこういうことがなかった。つだをはなかなかれるるせいである。
# 「どうもそんなことゆった。けれどもれいかのいもうものせうちあいさせるが、そとをこんだまなかった。けれどもちかみめいなやはながあるかぜしなにはできていないから、ことについてようにちのうのことはんだからぜひのほうである。あ
#
# ----- diversity: 1.2
# ----- Generating with seed: "とうきよがさいそくするから、かたくかたくのにがくはめんかれぬ。とうざいのあるけん"
# とうきよがさいそくするから、かたくかたくのにがくはめんかれぬ。とうざいのあるけんひとすじのなにざすふたまからながらさのだしらつきなわら、じっといっくるばかりやどうさ。たっかじなのしょがへよめへいって。かいわはにいつをさんちらどかれのふれつなならげたてをきく、
# 「え、むかあさんしおりてしゃじょうはきこえよすのとつだとおっしゃい。どうしたときは、くらしゃしょさいなんだろうというものであったが、うえざら、りがわせへんだかもは、おとんまとちはてんそだったことがなかろうかと、だんだんの。いかげんかわりになんくあ」とかのじょをよんだ。じぶんがけいほかわった。やけがたとてもわたしがわをかけることをした。かのじょはいちかってすわ、ちょっとばかばなぜつうまじめまいぶぶらざらまずくわのひざひざのてにかかのきのくふうをのぞきのめいげんしてくわまみ、まちちぎげょして、てんきゅうおあつりともあったようにむさんりよがたいてをはいてみていないから、わらったのはむすけすびとこわされって、すいじょうひ
#
# --------------------------------------------------
# Iteration 14
# Epoch 1/1
# 735812/735812 [==============================] - 634s 861us/step - loss: 2.4492
#
# ----- diversity: 0.2
# ----- Generating with seed: "ちゃくしていた。
# いちにはこのかんほうもんしたときからのいんひっかかりがあった。"
# ちゃくしていた。
# いちにはこのかんほうもんしたときからのいんひっかかりがあった。
# 「あなたのいえうちへいくと、いつものものはない。だから、そういうから、おくさんのことだから、いつものもんだいです」
# 「いいえ」という。
# 「あなたのおんなのかおをみて、こういうことになったのです。わたしはそのときというのは、いままでもないのです。そうしてそのときは、いつもののちいちになって、そのうえにおいて、そのおとこだとおもって、そのときには、あなたはなにのなかになると、しょうじきなあいてになった。それからそのときのかんけいをかんがえて、そのときには、かれはただいまにもいわなかった。
# 「そうかんがえているんだ」
# 「いいえ」といいながら、
# 「いや、あなたはないとおもって」ときいた。
# 「おくさんはいままでもあるんだ」
# 「そうですか」
# 「そうですか」ときいた。
# 「おいて」ときいた。
# 「いままでもない」
# 「そうですか」
# 「ええ」
# 「そうです。それでもかまわないから」
# 「いいえ」という。
# 「きみ、
#
# ----- diversity: 0.5
# ----- Generating with seed: "ちゃくしていた。
# いちにはこのかんほうもんしたときからのいんひっかかりがあった。"
# ちゃくしていた。
# いちにはこのかんほうもんしたときからのいんひっかかりがあった。
# とうきょうはなにからにいさんにはいって、しょうじしょうじをいしていた。
# 「つまさえあなたのかおをならなかったのです。またはははつきというのは、いっそうしている。
# 「そうですか」
# 「そうかんがえて、ふじんのしょうせつにおもいました。
# おんなはもうすこしみていた。
# 「ええ。いくらきょうみたときは、きりょうまえから、ごこめはちょっといっちゃをするというのです。わたしはいまからみなみんなとおりて、そういうときに、あるいがまわしました。そうしてそのかわりにいたらいいのです。そのかんでははははたしかにすわっていた。かれはいままではいいのです。そのときごしゅうしゅくしゅうじょうをはなして、いしゃのしょさいに、それをあおうとして、このかんがえのうちに、このおくさんはまたはかのじょのうちで、ふたりのまえにながめていた。
# 「じゃ、いままでしょうかいしているんだから、おんなのわたしのこういなんだ」
# 「いくらい
#
# ----- diversity: 1.0
# ----- Generating with seed: "ちゃくしていた。
# いちにはこのかんほうもんしたときからのいんひっかかりがあった。"
# ちゃくしていた。
# いちにはこのかんほうもんしたときからのいんひっかかりがあった。どんじにあたらしにきるまい、みはもうももあねまかけ「にたくさんばあるのがぬけているんだがあ。あれだって、まえにやまってい」
# 「まあよってみてきるうちに、きてくれば」
# こえがすようとしていたのでした。かれがそこにすみではらくらいののれっば、あにはふたりでもなくわまわしてだいだいにがとがせました。ものどれいのぼんやうしろとうととはなのつごうかまたきくみかきにうすんである。
# 「あたしのわたしたんだ。どうしてあうとをはてらすんです。そうじゃあるんです。だいすわろです。まだあなたにたいてみまのきによまであたりそうなかんにでいきていた。けれどもおんながあのなかなまだいしにいでもいえのひをていすんのいたの、とくどりようとうのものをみなかったが、はらのうえにみねこがはいぶんていどにおいてはんしゃしていいたままあるみいろがもじぶんでつかくしてくるくりをどうかせわかしてねて、こういのほうからきえたのです。わた
#
# ----- diversity: 1.2
# ----- Generating with seed: "ちゃくしていた。
# いちにはこのかんほうもんしたときからのいんひっかかりがあった。"
# ちゃくしていた。
# いちにはこのかんほうもんしたときからのいんひっかかりがあった。みもとうまで、かえったば、そのかおがさこちゃうはいちめんにこころむじせんとにいさんに、
# 「きょうはふの、どここのなのかかどうようるくらいのかくい」
# むねすけはおれあてすりづれ、とうきょうへつづいてしまされている。まずが、そとまではひくったままんきばうにゆったのでもない。
# 「みんがすみかふたるぎてであわあいながらでなきろう。つまりあおむのもあいてもかれねべっぱなどぷ。みんなつだのきえばとられられた。
# ざすけはまえまでぶらいなせいとないとかくかたづけもこうへはいいがたでてぼうのなかくんででるのところで、よしをすこしだしてかがないかぐそなくこもははなくする。おはたちわにかがはながてあたることである。それがすに、ふうふさんにきんがこわらえみらなかったね、じゅらぬわずかなせっきほかにかつよとうよくにくやびるいきゃくよりしょうしょくもくじとひとつづいいしてらこきがじゅんいですごしそうにせいじてきしゃら
#
# --------------------------------------------------
# Iteration 15
# Epoch 1/1
# 735812/735812 [==============================] - 634s 862us/step - loss: 2.4438
#
# ----- diversity: 0.2
# ----- Generating with seed: "あのゆかとこにささしてある」
# ろうじんはいながら、かおのむかいをこううしろへかえ"
# あのゆかとこにささしてある」
# ろうじんはいながら、かおのむかいをこううしろへかえって、「おのさん」ということばをおもいだした。
# 「きょうはいったんですか」
# 「ええ」
# 「そうか。それでもあるところで、それでもかんがえると、それでもかのじょのいえうちへはいった。
# 「きょうはどうでもよい。それでもかんがえると、それでもあるときのうえにあるいているんだろう」
# 「そうか」
# 「そうか、あたしのあたまにいると、それでもいいから」
# 「そうですか」
# 「ええ」
# 「なにかおのべはあなたのまえにあいては、すこしもくしょうしているんだから」
# 「そうか」
# 「そうか。おのさんはあたしのようにおもっていたんですか」
# 「なにもかえりますから」
# 「そうか」
# 「そうか」
# 「そうか」
# 「そうか」
# 「そうか」
# 「そうか」
# 「そうか」
# 「いえ、あなたのいえうちにいるんだろう」
# 「あのおんな」とおもった。
# 「どうしても、どうして、あなたのいえうちへいって」
# 「なにかわいにいっているんだから」
# 「そうか」
# 「そうか
#
# ----- diversity: 0.5
# ----- Generating with seed: "あのゆかとこにささしてある」
# ろうじんはいながら、かおのむかいをこううしろへかえ"
# あのゆかとこにささしてある」
# ろうじんはいながら、かおのむかいをこううしろへかえすから、「そんなあたりのないから、これからぼくのしょうじをおきついていたのです。だからなくっても、それでいうと、いつまでも、そらからえんりょしているんですか」
# 「なにかもしれないのか、あなたはしょうじである。いまでもよういにあたまのないのです。おのさんはそういうことばをもっていた。じぶんはそれをみんながいにいかない。
# 「どうして、なにのないのは、しかたがない。おくさんのおとことおなじことです」
# 「それでもあんなやりたまりからだから」
# 「そう」
# 「あなたがわからないのでしょう」
# 「だって、どうするものか」
# 「そうか、あたしはまだかくのおおいかってならなかったのです。このころくはなにかからだしたんですか」
# 「あいさつあいさわしいかわりにおかしいのか」ときいた。
# 「そうか。それでもかんがえるようなものですか」とおんなはこういった。
# 「そう、るからなにかいいでしょう」
# 「おんながしんだ。そうしてこ
#
# ----- diversity: 1.0
# ----- Generating with seed: "あのゆかとこにささしてある」
# ろうじんはいながら、かおのむかいをこううしろへかえ"
# あのゆかとこにささしてある」
# ろうじんはいながら、かおのむかいをこううしろへかえったれいをおんなのたくへがえにおおいにかえりみた。かれにはかならばならぬのげいじょう、そこにうぜくうえのげえにんぶんはほんとうじゃ、むねすけはあまりそのそくらってごめんきゅうかからあるからない」とゆった。
# あにころはいくらだいしからったおのべを、にだいにやすいいようにあさなければじりよりもありますから、どうかいふんしばいにしてくるんですか。するどなりましき。きいたの、ましもとよるのか。あなたもねついつきでもだうじょうあいかよりゅうからがっこうですでにいったったから、かえってくらくなった。
# 「むずかしい」
# おのなをそこだときっここんほおほそいていたかわいてあたまをおかしてわるいのでそうようにするつなこうじをひきそえたのである。
# 「まだきこえたわ、まよけんができないってそれをかいてあまっていそいついんだね。そのじうかんかなりこたえないむかしきめてしまもないとおもってきた。それもますますよ」
# 「
#
# ----- diversity: 1.2
# ----- Generating with seed: "あのゆかとこにささしてある」
# ろうじんはいながら、かおのむかいをこううしろへかえ"
# あのゆかとこにささしてある」
# ろうじんはいながら、かおのむかいをこううしろへかえした。たんとへいにでふみまぐさまをのべてもしゆびでてついてにながらあたらきりみんどいとのうえうちくるおうじかかわかろうそよむひだりりはくにやのかいわんふうをおもしもばあさいさょふにしてやれるだらがらすれいるためめわめつえんまでぎょうぎつうという、しろくあやいという。かんけいへしょうだぐやはかえらそうすすじのなかおいつげなわらくえている。すぐはんねんにあいそうをすまなかおねなかった。ただおとこにはかずの。よんどまでがでるさえ、
# よさせながら、かれのめじょうろになってかえるりもないのである。
# ぐなねとどこにびしょうへそこさへまってきかいさきにこまれて、そといへんなしきゃくであったまかろうと、かのじょはてらにしばらきがちらくたりだがまったくさらなかった。
# 「うきほんとうつともなんでもらかせるようにりなうなっとつごうをかもしちます」
# 「ふたり、です。てんかいはどうあげめだったが、くちできかるかわか
#
# --------------------------------------------------
# Iteration 16
# Epoch 1/1
# 163328/735812 [=====>........................] - ETA: 8:18 - loss: 2.4238

# %%
# !ls -a
